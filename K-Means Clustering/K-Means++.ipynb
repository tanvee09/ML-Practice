# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=500, n_features=2, centers=5, random_state=6)

# %%
from sklearn.cluster import KMeans

# %%
KMeans?

# %%
plt.scatter(X[:, 0], X[:, 1], c = y)
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(X, y)
# Out:
# KMeans(n_clusters=5)

# %%
centers = kmeans.cluster_centers_
print(centers)
# Out:
# [[ 0.61541772 -1.73098083]
#  [-7.82716442  1.82865429]
#  [ 7.91945636 -3.29257186]
#  [ 6.49057282 -9.07595071]
#  [-3.32447703  2.43900288]]

# %%
plt.scatter(X[:, 0], X[:, 1], c = y)
plt.scatter(centers[:, 0], centers[:, 1], marker = 'x', color = 'red')
plt.show()

# %%
pred = kmeans.labels_

# %%
print(pred)
# Out:
# [1 2 0 2 3 1 2 2 1 2 4 4 3 2 3 3 3 2 4 0 3 1 2 3 2 2 0 1 0 0 2 0 3 2 3 3 3
#  4 1 0 4 1 0 3 1 1 0 1 4 4 0 1 2 3 1 0 2 2 2 1 4 2 0 0 2 3 1 3 0 4 3 0 4 3
#  3 0 1 2 0 2 0 3 0 2 0 2 3 0 1 2 3 3 0 0 4 0 2 3 1 2 4 1 3 2 3 1 3 4 2 2 2
#  0 2 1 2 1 3 1 4 2 4 4 1 2 2 3 4 0 1 0 4 4 3 0 1 3 0 2 4 1 0 0 3 2 4 2 4 1
#  2 2 0 2 1 0 3 3 4 3 1 3 4 0 1 0 1 2 1 2 1 4 1 1 2 1 4 0 4 3 1 1 3 1 4 4 1
#  3 3 3 3 2 0 2 1 3 0 3 4 0 1 0 4 1 0 3 2 4 4 4 0 3 2 3 2 0 0 4 1 1 1 2 0 4
#  4 3 2 2 1 4 1 0 2 0 0 4 3 1 1 4 4 0 3 1 3 0 3 2 0 4 0 3 0 1 3 3 0 4 2 3 0
#  3 0 1 1 4 4 4 1 2 0 0 3 3 2 4 4 3 4 0 2 0 0 0 4 4 0 4 2 3 0 1 2 4 0 3 2 2
#  3 4 1 1 3 4 2 3 4 0 3 4 0 4 1 2 2 1 3 0 4 4 2 2 4 2 3 2 1 0 4 1 1 2 2 4 0
#  4 3 0 2 4 4 1 1 2 4 3 3 4 2 3 0 0 0 4 0 1 2 4 2 4 3 1 0 4 3 0 0 3 3 2 3 2
#  4 0 1 1 0 0 4 4 4 4 4 1 4 1 3 3 0 0 1 3 4 1 2 2 2 3 3 1 2 1 3 1 0 1 1 4 3
#  3 3 3 2 0 4 0 0 3 3 1 0 1 1 0 4 1 4 1 3 2 0 2 0 3 1 2 1 3 2 1 1 4 4 0 2 3
#  2 4 2 0 2 1 2 1 4 4 4 2 3 2 1 2 4 1 1 1 4 0 4 4 0 1 4 4 3 1 4 0 1 1 3 2 1
#  3 3 4 3 4 2 0 1 3 0 2 4 2 3 0 0 3 1 1]

# %%
plt.scatter(X[:, 0], X[:, 1], c = pred)
plt.scatter(centers[:, 0], centers[:, 1], color = "red", marker='x')
plt.show()
