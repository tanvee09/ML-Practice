# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
images = np.load('./data/A.npy')

# %%
type(images)
# Out:
# numpy.ndarray

# %%
images.shape
# Out:
# (10, 10000)

# %%
print(images)
# Out:
# [[183 185 185 ... 122 134 144]
#  [194 189 180 ...  34  35  36]
#  [176 164  93 ...  74  83 104]
#  ...
#  [184 184 183 ...  72  98 127]
#  [180 182 180 ... 110 110 119]
#  [180 180 179 ... 133 143 156]]

# %%
for img in images :
    plt.imshow(img.reshape((100, 100, -1)), cmap = 'gray')
    plt.axis("off")
    plt.show()
