# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
images = np.load('./data/A.npy')

# %%
type(images)
# Out:
# numpy.ndarray

# %%
images.shape
# Out:
# (2, 10000)

# %%
print(images)
# Out:
# [[ 67  64  60 ... 177 162 144]
#  [ 48  35  32 ... 184 200 204]]

# %%
for img in images :
    plt.imshow(img.reshape((100, 100, -1)), cmap = 'gray')
    plt.show()
