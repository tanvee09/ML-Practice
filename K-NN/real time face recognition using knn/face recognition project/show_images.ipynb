# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
images = np.load('./data/tanvee.npy')

# %%
type(images)
# Out:
# numpy.ndarray

# %%
images.shape
# Out:
# (10, 10000)

# %%
print(images)
# Out:
# [[143 143 139 ... 146 172 175]
#  [126 100 101 ... 175 177 173]
#  [144 128 100 ... 177 140 154]
#  ...
#  [154 155 155 ... 174 142 156]
#  [ 82  74  63 ... 173 177 171]
#  [ 29  29  26 ... 181 183 171]]

# %%
for img in images :
    plt.imshow(img.reshape((100, 100, -1)), cmap = 'gray')
    plt.axis("off")
    plt.show()
