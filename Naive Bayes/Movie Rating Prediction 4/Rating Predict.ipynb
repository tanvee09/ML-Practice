# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Train.csv')
data = df.values

# %%
df.head()
# Out:
#                                               review label
# 0  mature intelligent and highly charged melodram...   pos
# 1  http://video.google.com/videoplay?docid=211772...   pos
# 2  Title: Opera (1987) Director: Dario Argento Ca...   pos
# 3  I think a lot of people just wrote this off as...   pos
# 4  This is a story of two dogs and a cat looking ...   pos

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

# %%
tokenizer = RegexpTokenizer("[A-Za-z-']+")
en_stopwords = set(stopwords.words('english'))
ps = PorterStemmer()

# %%
from bs4 import BeautifulSoup
import regex as re

# %%
def getStemmedReview(review) :
    review = review.lower()
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    review = url_pattern.sub(r' ', review)
    soup = BeautifulSoup(review, 'html.parser')
    review = soup.get_text(separator = ' ')
    tokens = tokenizer.tokenize(review)
    new_tokens = [token for token in tokens if token not in en_stopwords]
    stemmed_tokens = [ps.stem(token) for token in new_tokens]
    cleaned_review = ' '.join(stemmed_tokens)
    return cleaned_review

# %%
data[1, 0]
# Out:
# 'http://video.google.com/videoplay?docid=211772166650071408&hl=en Distribution was tried.<br /><br />We opted for mass appeal.<br /><br />We want the best possible viewing range so, we forgo profit and continue our manual labor jobs gladly to entertain you for working yours.<br /><br />View Texas tale, please write about it... If you like it or not, if you like Alex or not, if you like Stuie, Texas or Texas tale... Just write about it.<br /><br />Your opinion rules.'

# %%
getStemmedReview(data[1, 0])
# Out:
# 'distribut tri opt mass appeal want best possibl view rang forgo profit continu manual labor job gladli entertain work view texa tale pleas write like like alex like stuie texa texa tale write opinion rule'

# %%
def getStemmedDocument(document) :
    output = []
    for review in document :
        output.append(getStemmedReview(review))
    return output

# %%
cleaned_document = getStemmedDocument(data[:, 0])

# %%
cleaned_document[0]
# Out:
# "matur intellig highli charg melodrama unbelivebl film china wei wei' stun perform catylast love triangl simpli stun oppurun see magnific film take"

# %%
cleaned_document[1]
# Out:
# 'distribut tri opt mass appeal want best possibl view rang forgo profit continu manual labor job gladli entertain work view texa tale pleas write like like alex like stuie texa texa tale write opinion rule'

# %%
cleaned_document[2]
# Out:
# "titl opera director dario argento cast cristina masillach ian charleson urbano barberini daria nicolodi review argento movi seen suspiria one blew away style color spooki stori line next decid go opera told one best man think i'm discov ultim one favorit horror director opera young opera singer get big break main star creepi modern opera take mc beth get hit car betti understudi get part bad there' psycho make watch brutal murder friend co-work wow id heard good thing flick prepar level great film would take yeah movi shortcom ill get later part movi blew away first movi fill lot color suspiria expect bit like suspiria depart surpris look feel film somehow devoid color lot color certain scene like master kitchen live room sequenc argento fill screen lush green blue part film grayish black tone like distinct look real star show incred well orchestr death sequenc wow everi death scene like work art beauti destruct typic hack slash death sequenc death care construct shock get situat love everi second there' plenti blood mayhem style gonna spoil em though there' direct man there' realli origin beauti shot one love invent use camera one thought tarantino shot kill bill vol see bullet come chamber gun origin well movi lift honestli believ tarantino heavili influenc specif movi certain scene kill bill vol heck make featur mention whole scene beatrix hospit ell driver come kill influenc italian giallo friend proof anyhow tarantino refer asid movi amaz camera shot like scene crow fli crowd opera hous great stuff main reason argento becom one favorit act cast alright best far cristina marsillach tortur young opera singer betti look eye murder commit great rest cast littl wooden stiff noth would deter enjoy film thing like movi first logic thrown window certain scene special involv betti reaction she seen murder seem longest time went busi tell anyon whole thing even polic mean see someon brutal murder love one front eye walk away murder scene continu life someon would connect murder might even becom suspect also end bit anti climact see understand seem bit unnecessari way film end felt like could end earlier would felt redund that real big problem realli sinc enjoy rest beauti film i'v still got lot argento territori cover i'm devour everi step way like eat plate expens caviar guy realli good think film work art i'v seen two em cant wait discov rest film argento man rate"

# %%
y = data[:, 1]

# %%
Y = []
for i in y :
    if i == 'pos' :
        Y.append(1)
    else :
        Y.append(0)

# %%
Y[:10]
# Out:
# [1, 1, 1, 1, 1, 1, 0, 0, 1, 1]

# %%
 X = cleaned_document

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(ngram_range=(1, 2))

x_vec = cv.fit_transform(X)
print(x_vec[3, :].toarray())
print(x_vec.shape)
# Out:
# [[0 0 0 ... 0 0 0]]
# (40000, 2286831)

# %%
dftest = pd.read_csv('Test.csv')

# %%
x_test_raw = dftest.values[:, 0]

# %%
x_test = getStemmedDocument(x_test_raw)

# %%
cv.vocabulary_
# Out:
# {'matur': 1243991,
#  'intellig': 1021167,
#  'highli': 931979,
#  'charg': 322128,
#  'melodrama': 1259189,
#  'unbelivebl': 2111935,
#  'film': 730217,
#  'china': 336168,
#  'wei': 2206116,
#  'stun': 1938369,
#  'perform': 1478804,
#  'catylast': 302521,
#  'love': 1189553,
#  'triangl': 2084540,
#  'simpli': 1823513,
#  'oppurun': 1423336,
#  'see': 1756141,
#  'magnific': 1208516,
#  'take': 1979343,
#  'matur intellig': 1244097,
#  'intellig highli': 1021459,
#  'highli charg': 932030,
#  'charg melodrama': 322329,
#  'melodrama unbelivebl': 1259426,
#  'unbelivebl film': 2111936,
#  'film china': 731388,
#  'china wei': 336389,
#  'wei wei': 2206129,
#  'wei stun': 2206127,
#  'stun perform': 1938656,
#  'perform catylast': 1479192,
#  'catylast love': 302522,
#  'love triangl': 1192850,
#  'triangl simpli': 2084628,
#  'simpli stun': 1824528,
#  'stun oppurun': 1938642,
#  'oppurun see': 1423337,
#  'see magnific': 1758727,
#  'magnific film': 1208622,
#  'film take': 736929,
#  'distribut': 546635,
#  'tri': 2082388,
#  'opt': 1423380,
#  'mass': 1237065,
#  'appeal': 97771,
#  'want': 2183037,
#  'best': 190246,
#  'possibl': 1536032,
#  'view': 2162404,
#  'rang': 1604526,
#  'forgo': 773714,
#  'profit': 1567473,
#  'continu': 411114,
#  'manual': 1228329,
#  'labor': 1101300,
#  'job': 1054281,
#  'gladli': 838058,
#  'entertain': 628328,
#  'work': 2249142,
#  'texa': 2008872,
#  'tale': 1982976,
#  'pleas': 1514064,
#  'write': 2264390,
#  'like': 1148862,
#  'alex': 48823,
#  'stuie': 1938182,
#  'opinion': 1421160,
#  'rule': 1703461,
#  'distribut tri': 546805,
#  'tri opt': 2083475,
#  'opt mass': 1423422,
#  'mass appeal': 1237075,
#  'appeal want': 98371,
#  'want best': 2183210,
#  'best possibl': 191561,
#  'possibl view': 1537224,
#  'view rang': 2163454,
#  'rang forgo': 1604660,
#  'forgo profit': 773721,
#  'profit continu': 1567491,
#  'continu manual': 411596,
#  'manual labor': 1228338,
#  'labor job': 1101345,
#  'job gladli': 1054820,
#  'gladli entertain': 838070,
#  'entertain work': 629736,
#  'work view': 2252237,
#  'view texa': 2163733,
#  'texa tale': 2009078,
#  'tale pleas': 1983528,
#  'pleas write': 1514689,
#  'write like': 2264932,
#  'like like': 1152670,
#  'like alex': 1148996,
#  'alex like': 48970,
#  'like stuie': 1155208,
#  'stuie texa': 1938186,
#  'texa texa': 2009080,
#  'tale write': 1983783,
#  'write opinion': 2265052,
#  'opinion rule': 1421745,
#  'titl': 2050455,
#  'opera': 1420571,
#  'director': 532176,
#  'dario': 471444,
#  'argento': 105496,
#  'cast': 297036,
#  'cristina': 450350,
#  'masillach': 1236379,
#  'ian': 976745,
#  'charleson': 323301,
#  'urbano': 2137323,
#  'barberini': 159073,
#  'daria': 471387,
#  'nicolodi': 1369278,
#  'review': 1670074,
#  'movi': 1316781,
#  'seen': 1764566,
#  'suspiria': 1969788,
#  'one': 1412044,
#  'blew': 211810,
#  'away': 140332,
#  'style': 1940921,
#  'color': 372217,
#  'spooki': 1889043,
#  'stori': 1919821,
#  'line': 1158608,
#  'next': 1366018,
#  'decid': 488515,
#  'go': 841390,
#  'told': 2055751,
#  'man': 1218934,
#  'think': 2024335,
#  'discov': 538744,
#  'ultim': 2108748,
#  'favorit': 711566,
#  'horror': 955386,
#  'young': 2279697,
#  'singer': 1828672,
#  'get': 822998,
#  'big': 197771,
#  'break': 239828,
#  'main': 1209644,
#  'star': 1898624,
#  'creepi': 446193,
#  'modern': 1295377,
#  'mc': 1248688,
#  'beth': 192641,
#  'hit': 938442,
#  'car': 285420,
#  'betti': 195326,
#  'understudi': 2117702,
#  'part': 1455290,
#  'bad': 149728,
#  'there': 2017221,
#  'psycho': 1578760,
#  'make': 1212617,
#  'watch': 2190773,
#  'brutal': 253879,
#  'murder': 1332463,
#  'friend': 790143,
#  'co': 365563,
#  'wow': 2262489,
#  'id': 977657,
#  'heard': 914623,
#  'good': 850308,
#  'thing': 2021568,
#  'flick': 757324,
#  'prepar': 1547938,
#  'level': 1138617,
#  'great': 866031,
#  'would': 2259301,
#  'yeah': 2273066,
#  'shortcom': 1804731,
#  'ill': 983319,
#  'later': 1112965,
#  'first': 747669,
#  'fill': 729324,
#  'lot': 1185647,
#  'expect': 671891,
#  'bit': 203598,
#  'depart': 502442,
#  'surpris': 1964474,
#  'look': 1178584,
#  'feel': 716310,
#  'somehow': 1858564,
#  'devoid': 518010,
#  'certain': 308709,
#  'scene': 1731455,
#  'master': 1238004,
#  'kitchen': 1089282,
#  'live': 1167543,
#  'room': 1695806,
#  'sequenc': 1775891,
#  'screen': 1744254,
#  'lush': 1199082,
#  'green': 870114,
#  'blue': 216309,
#  'grayish': 865826,
#  'black': 207164,
#  'tone': 2058450,
#  'distinct': 545643,
#  'real': 1616003,
#  'show': 1807878,
#  'incred': 1000880,
#  'well': 2207786,
#  'orchestr': 1424256,
#  'death': 484152,
#  'everi': 654094,
#  'art': 112710,
#  'beauti': 171314,
#  'destruct': 512866,
#  'typic': 2106096,
#  'hack': 887251,
#  'slash': 1839237,
#  'care': 287059,
#  'construct': 407923,
#  'shock': 1800441,
#  'situat': 1833327,
#  'second': 1752959,
#  'plenti': 1515428,
#  'blood': 213762,
#  'mayhem': 1248202,
#  'gonna': 850020,
#  'spoil': 1887171,
#  'em': 608297,
#  'though': 2029614,
#  'direct': 529874,
#  'realli': 1621127,
#  'origin': 1426533,
#  'shot': 1805184,
#  'invent': 1031574,
#  'use': 2140239,
#  'camera': 276303,
#  'thought': 2031823,
#  'tarantino': 1988871,
#  'kill': 1081128,
#  'bill': 200549,
#  'vol': 2174828,
#  'bullet': 259914,
#  'come': 375026,
#  'chamber': 312356,
#  'gun': 881976,
#  'lift': 1146306,
#  'honestli': 949167,
#  'believ': 182792,
#  'heavili': 918272,
#  'influenc': 1008399,
#  'specif': 1880420,
#  'heck': 918628,
#  'featur': 714196,
#  'mention': 1264451,
#  'whole': 2221786,
#  'beatrix': 171095,
#  'hospit': 957301,
#  'ell': 605869,
#  'driver': 572548,
#  'italian': 1040977,
#  'giallo': 828167,
#  'proof': 1571387,
#  'anyhow': 90254,
#  'refer': 1634330,
#  'asid': 116903,
#  'amaz': 67712,
#  'crow': 453207,
#  'fli': 756698,
#  'crowd': 453325,
#  'hous': 960688,
#  'stuff': 1937257,
#  'reason': 1623938,
#  'becom': 174101,
#  'act': 13634,
#  'alright': 59350,
#  'far': 703237,
#  'marsillach': 1234554,
#  'tortur': 2063586,
#  'eye': 683447,
#  'commit': 383925,
#  'rest': 1662782,
#  'littl': 1164654,
#  'wooden': 2246775,
#  'stiff': 1912615,
#  'noth': 1382411,
#  'deter': 514702,
#  'enjoy': 622782,
#  'logic': 1174271,
#  'thrown': 2039112,
#  'window': 2231451,
#  'special': 1879544,
#  'involv': 1033271,
#  'reaction': 1613597,
#  'she': 1795257,
#  'seem': 1761549,
#  'longest': 1178327,
#  'time': 2043731,
#  'went': 2211581,
#  'busi': 264765,
#  'tell': 1999333,
#  'anyon': 90706,
#  'even': 646740,
#  'polic': 1524764,
#  'mean': 1251319,
#  'someon': 1859167,
#  'front': 793785,
#  'walk': 2179743,
#  'life': 1142775,
#  'connect': 401985,
#  'might': 1275041,
#  'suspect': 1968216,
#  'also': 59566,
#  'end': 614875,
#  'anti': 88470,
#  'climact': 359163,
#  'understand': 2116057,
#  'unnecessari': 2128606,
#  'way': 2197048,
#  'felt': 719804,
#  'could': 426429,
#  'earlier': 586509,
#  'redund': 1633463,
#  'that': 2011279,
#  'problem': 1561054,
#  'sinc': 1825825,
#  'still': 1912945,
#  'got': 856674,
#  'territori': 2007070,
#  'cover': 435324,
#  'devour': 518418,
#  'step': 1909006,
#  'eat': 590415,
#  'plate': 1508034,
#  'expens': 673656,
#  'caviar': 304709,
#  'guy': 883929,
#  'two': 2102189,
#  'cant': 282198,
#  'wait': 2178292,
#  'rate': 1607925,
#  'titl opera': 2051150,
#  'opera director': 1420669,
#  'director dario': 532691,
#  'dario argento': 471445,
#  'argento cast': 105515,
#  'cast cristina': 297433,
#  'cristina masillach': 450360,
#  'masillach ian': 1236380,
#  'ian charleson': 976754,
#  'charleson urbano': 323307,
#  'urbano barberini': 2137324,
#  'barberini daria': 159075,
#  'daria nicolodi': 471405,
#  'nicolodi review': 1369285,
#  'review argento': 1670141,
#  'argento movi': 105585,
#  'movi seen': 1322245,
#  'seen suspiria': 1766750,
#  'suspiria one': 1969803,
#  'one blew': 1412522,
#  'blew away': 211815,
#  'away style': 141919,
#  'style color': 1941121,
#  'color spooki': 372782,
#  'spooki stori': 1889149,
#  'stori line': 1921794,
#  'line next': 1159720,
#  'next decid': 1366211,
#  'decid go': 488814,
#  'go opera': 843289,
#  'opera told': 1420972,
#  'told one': 2056286,
#  'one best': 1412477,
#  'best man': 191306,
#  'man think': 1221589,
#  'think discov': 2025109,
#  'discov ultim': 539506,
#  'ultim one': 2109186,
#  'one favorit': 1413819,
#  'favorit horror': 711883,
#  'horror director': 955638,
#  'director opera': 533761,
#  'opera young': 1421020,
#  'young opera': 2280632,
#  'opera singer': 1420917,
#  'singer get': 1828807,
#  'get big': 823326,
#  'big break': 197936,
#  'break main': 240266,
#  'main star': 1210077,
#  'star creepi': 1899055,
#  'creepi modern': 446489,
#  'modern opera': 1295732,
#  'opera take': 1420951,
#  'take mc': 1980698,
#  'mc beth': 1248690,
#  'beth get': 192658,
#  'get hit': 824625,
#  'hit car': 938568,
#  'car betti': 285505,
#  'betti understudi': 195503,
#  'understudi get': 2117707,
#  'get part': 825463,
#  'part bad': 1455470,
#  'bad there': 151761,
#  'there psycho': 2018163,
#  'psycho make': 1578908,
#  'make watch': 1216169,
#  'watch brutal': 2191227,
#  'brutal murder': 254130,
#  'murder friend': 1332973,
#  'friend co': 790488,
#  'co work': 365792,
#  'work wow': 2252352,
#  'wow id': 2262631,
#  'id heard': 977683,
#  'heard good': 914947,
#  'good thing': 853234,
#  'thing flick': 2022501,
#  'flick prepar': 758089,
#  'prepar level': 1548154,
#  'level great': 1139023,
#  'great film': 866946,
#  'film would': 737829,
#  'would take': 2261711,
#  'take yeah': 1981860,
#  'yeah movi': 2273281,
#  'movi shortcom': 1322374,
#  'shortcom ill': 1804770,
#  'ill get': 983448,
#  'get later': 824917,
#  'later part': 1113894,
#  'part movi': 1456856,
#  'movi blew': 1317437,
#  'away first': 140952,
#  'first movi': 748931,
#  'movi fill': 1319091,
#  'fill lot': 729711,
#  'lot color': 1185973,
#  'color suspiria': 372807,
#  'suspiria expect': 1969796,
#  'expect bit': 672041,
#  'bit like': 204608,
#  'like suspiria': 1155302,
#  'suspiria depart': 1969793,
#  'depart surpris': 502728,
#  'surpris look': 1965101,
#  'look feel': 1179613,
#  'feel film': 716983,
#  'film somehow': 736494,
#  'somehow devoid': 1858688,
#  'devoid color': 518029,
#  'color lot': 372563,
#  'color certain': 372297,
#  'certain scene': 309190,
#  'scene like': 1733707,
#  'like master': 1152927,
#  'master kitchen': 1238349,
#  'kitchen live': 1089347,
#  'live room': 1169297,
#  'room sequenc': 1696561,
#  'sequenc argento': 1775946,
#  'argento fill': 105550,
#  'fill screen': 729900,
#  'screen lush': 1745067,
#  'lush green': 1199107,
#  'green blue': 870155,
#  'blue part': 216600,
#  'part film': 1456167,
#  'film grayish': 733143,
#  'grayish black': 865827,
#  'black tone': 208118,
#  'tone like': 2058704,
#  'like distinct': 1150685,
#  'distinct look': 545753,
#  'look real': 1180832,
#  'real star': 1617666,
#  'star show': 1900410,
#  'show incred': 1809537,
#  'incred well': 1001673,
#  'well orchestr': 2209871,
#  'orchestr death': 1424280,
#  'death sequenc': 485328,
#  'sequenc wow': 1777099,
#  'wow everi': 2262576,
#  'everi death': 654346,
#  'death scene': 485310,
#  'like work': 1156154,
#  'work art': 2249310,
#  'art beauti': 112785,
#  'beauti destruct': 171695,
#  'destruct typic': 513134,
#  'typic hack': 2106415,
#  'hack slash': 887407,
#  'slash death': 1839262,
#  'sequenc death': 1776134,
#  'death care': 484353,
#  'care construct': 287279,
#  'construct shock': 408134,
#  'shock get': 1800696,
#  'get situat': 826152,
#  'situat love': 1833829,
#  'love everi': 1190596,
#  'everi second': 654948,
#  'second there': 1753895,
#  'there plenti': 2018120,
#  'plenti blood': 1515475,
#  'blood mayhem': 214220,
#  'mayhem style': 1248287,
#  'style gonna': 1941394,
#  'gonna spoil': 850173,
#  'spoil em': 1887250,
#  'em though': 608438,
#  'though there': 2031575,
#  'there direct': 2017530,
#  'direct man': 530973,
#  'man there': 1221583,
#  'there realli': 2018182,
#  'realli origin': 1622586,
#  'origin beauti': 1426665,
#  'beauti shot': 172701,
#  'shot one': 1806437,
#  'one love': 1415030,
#  'love invent': 1191152,
#  'invent use': 1031911,
#  'use camera': 2140588,
#  'camera one': 276861,
#  'one thought': 1417090,
#  'thought tarantino': 2033428,
#  'tarantino shot': 1989017,
#  'shot kill': 1806176,
#  'kill bill': 1081303,
#  'bill vol': 201128,
#  'vol see': 2174846,
#  'see bullet': 1756705,
#  'bullet come': 259954,
#  'come chamber': 375372,
#  'chamber gun': 312383,
#  'gun origin': 882433,
#  'origin well': 1428294,
#  'well movi': 2209732,
#  'movi lift': 1320366,
#  'lift honestli': 1146403,
#  'honestli believ': 949186,
#  'believ tarantino': 184674,
#  'tarantino heavili': 1988938,
#  'heavili influenc': 918374,
#  'influenc specif': 1008756,
#  'specif movi': 1880583,
#  'movi certain': 1317767,
#  'scene kill': 1733592,
#  'vol heck': 2174837,
#  'heck make': 918749,
#  'make featur': 1213777,
#  'featur mention': 714943,
#  'mention whole': 1265747,
#  'whole scene': 2222574,
#  'scene beatrix': 1731787,
#  'beatrix hospit': 171096,
#  'hospit ell': 957404,
#  'ell driver': 605872,
#  'driver come': 572606,
#  'come kill': 376276,
#  'kill influenc': 1082045,
#  'influenc italian': 1008601,
#  'italian giallo': 1041127,
#  'giallo friend': 828209,
#  'friend proof': 791530,
#  'proof anyhow': 1571396,
#  'anyhow tarantino': 90323,
#  'tarantino refer': 1988995,
#  'refer asid': 1634376,
#  'asid movi': 117183,
#  'movi amaz': 1316996,
#  'amaz camera': 67821,
#  'camera shot': 277026,
#  'shot like': 1806221,
#  'like scene': 1154548,
#  'scene crow': 1732376,
#  'crow fli': 453242,
#  'fli crowd': 756833,
#  'crowd opera': 453537,
#  'opera hous': 1420747,
#  'hous great': 961251,
#  'great stuff': 868401,
#  'stuff main': 1937728,
#  'main reason': 1210032,
#  'reason argento': 1624016,
#  'argento becom': 105508,
#  'becom one': 175282,
#  'favorit act': 711570,
#  'act cast': 13993,
#  'cast alright': 297095,
#  'alright best': 59366,
#  'best far': 190893,
#  'far cristina': 703509,
#  'cristina marsillach': 450359,
#  'marsillach tortur': 1234565,
#  'tortur young': 2064086,
#  'singer betti': 1828713,
#  'betti look': 195433,
#  'look eye': 1179566,
#  'eye murder': 684226,
#  'murder commit': 1332716,
#  'commit great': 384062,
#  'great rest': 868053,
#  'rest cast': 1662877,
#  'cast littl': 298104,
#  'littl wooden': 1167308,
#  'wooden stiff': 2247029,
#  'stiff noth': 1912694,
#  'noth would': 1384116,
#  'would deter': 2259935,
#  'deter enjoy': 514709,
#  'enjoy film': 623373,
#  'film thing': 737057,
#  'thing like': 2022971,
#  'like movi': 1153225,
#  'movi first': 1319115,
#  'first logic': 748818,
#  'logic thrown': 1174623,
#  'thrown window': 2039476,
#  'window certain': 2231518,
#  'scene special': 1735061,
#  'special involv': 1879911,
#  'involv betti': 1033398,
#  'betti reaction': 195473,
#  'reaction she': 1613899,
#  'she seen': 1795371,
#  'seen murder': 1766028,
#  'murder seem': 1333619,
#  'seem longest': 1762889,
#  'longest time': 1178375,
#  'time went': 2048017,
#  'went busi': 2211702,
#  'busi tell': 265397,
#  'tell anyon': 1999399,
#  'anyon whole': 91613,
#  'whole thing': 2222726,
#  'thing even': 2022390,
#  'even polic': 649573,
#  'polic mean': 1525128,
#  'mean see': 1252602,
#  'see someon': 1760073,
#  'someon brutal': 1859292,
#  'murder love': 1333227,
#  'love one': 1191811,
#  'one front': 1414001,
#  'front eye': 793947,
#  'eye walk': 684750,
#  'walk away': 2179790,
#  'away murder': 141414,
#  'murder scene': 1333598,
#  'scene continu': 1732291,
#  'continu life': 411568,
#  'life someon': 1145133,
#  'someon would': 1860248,
#  'would connect': 2259780,
#  'connect murder': 402341,
#  'murder might': 1333285,
#  'might even': 1275403,
#  'even becom': 647057,
#  'becom suspect': 175736,
#  'suspect also': 1968237,
#  'also end': 60455,
#  'end bit': 615145,
#  'bit anti': 203664,
#  'anti climact': 88514,
#  'climact see': 359218,
#  'see understand': 1760549,
#  'understand seem': 2117129,
#  'seem bit': 1761761,
#  'bit unnecessari': 205507,
#  'unnecessari way': 2128905,
#  'way film': 2198189,
#  'film end': 732405,
#  'end felt': 615953,
#  'felt like': 720228,
#  'like could': 1150310,
#  'could end': 427020,
#  'end earlier': 615757,
#  'earlier would': 587011,
#  'would felt': 2260217,
#  'felt redund': 720385,
#  'redund that': 1633539,
#  'that real': 2012390,
#  'real big': 1616150,
#  'big problem': 198771,
#  'problem realli': 1562128,
#  'realli sinc': 1623022,
#  'sinc enjoy': 1826351,
#  'enjoy rest': 624116,
#  'rest beauti': 1662835,
#  'beauti film': 171869,
#  'film still': 736685,
#  'still got': 1913710,
#  'got lot': 857559,
#  'lot argento': 1185729,
#  'argento territori': 105608,
#  'territori cover': 2007111,
#  'cover devour': 435520,
#  'devour everi': 518428,
#  'everi step': 655043,
#  'step way': 1909473,
#  'way like': 2198839,
#  'like eat': 1150862,
#  'eat plate': 590777,
#  'plate expens': 1508059,
#  'expens caviar': 673687,
#  'caviar guy': 304711,
#  'guy realli': 885530,
#  'realli good': 1622048,
#  'good think': 853236,
#  'think film': 2025357,
#  'film work': 737815,
#  'art seen': 113459,
#  'seen two': 1766907,
#  'two em': 2102869,
#  'em cant': 608322,
#  'cant wait': 282326,
#  'wait discov': 2178498,
#  'discov rest': 539356,
#  'rest film': 1663036,
#  'film argento': 730562,
#  'argento man': 105578,
#  'man rate': 1221034,
#  'peopl': 1473118,
#  'wrote': 2268839,
#  'anoth': 85029,
#  'tom': 2057042,
#  'cruise': 454827,
#  'weird': 2206526,
#  'magnolia': 1208896,
#  'wide': 2224411,
#  'shut': 1814169,
#  'vanilla': 2150099,
#  'sky': 1837984,
#  'definit': 493633,
#  'mani': 1223745,
#  'said': 1712328,
#  'differ': 524362,
#  'confus': 400647,
#  'stanley': 1898212,
#  'kubrick': 1099104,
#  'pauli': 1467868,
#  'shore': 1803413,
#  'truman': 2092349,
#  'matrix': 1242154,
#  'game': 807204,
#  'unlik': 2127252,
#  'conclus': 397077,
#  'everyth': 656934,
#  'sens': 1771081,
#  'mayb': 1246702,
#  'immedi': 988086,
#  'today': 2052548,
#  'david': 476362,
#  'aam': 148,
#  'cruis': 454690,
#  'point': 1521252,
#  'so': 1852488,
#  'cal': 270627,
#  'turn': 2095958,
#  'critic': 450455,
#  'came': 274824,
#  'bother': 230594,
#  'open': 1419042,
#  'spanish': 1877131,
#  'enough': 625129,
#  'music': 1335078,
#  'cameron': 277388,
#  'offer': 1401338,
#  'wonder': 2243758,
#  'soundtrack': 1873599,
#  'set': 1782640,
#  'notori': 1385175,
#  'element': 603682,
#  'lack': 1101801,
#  'song': 1866017,
#  'beach': 168544,
#  'boys': 236297,
#  'vibrat': 2158976,
#  'play': 1508548,
#  'dramat': 565926,
#  'emot': 610671,
#  'climax': 359349,
#  'creat': 441810,
#  'offbeat': 1400678,
#  'yet': 2276662,
#  'astoundingli': 123305,
#  'right': 1678272,
#  'script': 1747164,
#  'imag': 984615,
#  'sadli': 1711011,
#  'superfici': 1957265,
#  'bandwagon': 157133,
#  'chide': 332566,
#  'order': 1424538,
#  'appear': 98425,
#  'excel': 664007,
#  'think lot': 2026003,
#  'lot peopl': 1187011,
#  'peopl wrote': 1475901,
#  'wrote anoth': 2268857,
#  'anoth one': 86355,
#  'one tom': 1417147,
#  'tom cruise': 2057132,
#  'cruise weird': 454839,
#  'weird movi': 2206878,
#  'movi magnolia': 1320517,
#  'magnolia eye': 1208907,
#  'eye wide': 684777,
#  'wide shut': 2224557,
#  'shut vanilla': 1814384,
#  'vanilla sky': 2150115,
#  'sky definit': 1838043,
#  'definit movi': 494161,
#  'movi mani': 1320545,
#  'mani peopl': 1225206,
#  'peopl said': 1475230,
#  'said weird': 1713656,
#  'weird differ': 2206667,
#  'differ confus': 524601,
#  'confus weird': 401437,
#  'weird weird': 2207114,
#  'weird stanley': 2207037,
#  'stanley kubrick': 1898259,
#  'kubrick pauli': 1099190,
#  'pauli shore': 1467922,
#  'shore differ': 1803438,
#  'differ truman': 525707,
#  'truman show': 2092374,
#  'show confus': 1808539,
#  'confus matrix': 401092,
#  'matrix game': 1242218,
#  'game unlik': 808325,
#  'unlik kubrick': 2127643,
#  'kubrick movi': 1099182,
#  'movi conclus': 1318036,
#  'conclus everyth': 397214,
#  'everyth make': 657610,
#  'make sens': 1215466,
#  'sens mayb': 1771872,
#  'mayb immedi': 1247330,
#  'immedi mayb': 988365,
#  'mayb even': 1247114,
#  'even today': 650556,
#  'today make': 2053012,
#  'sens vanilla': 1772445,
#  'sky confus': 1838036,
#  'confus david': 400802,
#  'david aam': 476363,
#  'aam tom': 156,
#  'tom cruis': 2057131,
#  'cruis confus': 454713,
#  'confus that': 401365,
#  'that point': 2012305,
#  'point that': 1523094,
#  'that so': 2012560,
#  'so cal': 1852517,
#  'cal weird': 270866,
#  'weird turn': 2207078,
#  'turn critic': 2096419,
#  'critic away': 450513,
#  'away came': 140541,
#  'came bother': 274937,
#  'bother open': 230875,
#  'open eye': 1419392,
#  'eye origin': 684279,
#  'origin spanish': 1428013,
#  'spanish movi': 1877283,
#  'movi would': 1323899,
#  'would seen': 2261412,
#  'seen that': 1766804,
#  'that enough': 2011708,
#  'enough reason': 626421,
#  'reason see': 1625138,
#  'see go': 1757911,
#  'go see': 843805,
#  'see music': 1758985,
#  'music cameron': 1335311,
#  'cameron crow': 277422,
#  'crow offer': 453269,
#  'offer wonder': 1402224,
#  'wonder soundtrack': 2245264,
#  'soundtrack use': 1874218,
#  'use set': 2142488,
#  'set feel': 1783367,
#  'feel notori': 717552,
#  'notori element': 1385229,
#  'element mani': 604145,
#  'mani movi': 1225044,
#  'movi lack': 1320261,
#  'lack song': 1102562,
#  'song like': 1866638,
#  'like beach': 1149395,
#  'beach boys': 168577,
#  'boys good': 236318,
#  'good vibrat': 853428,
#  'vibrat play': 2158995,
#  'play dramat': 1509639,
#  'dramat emot': 566073,
#  'emot climax': 610850,
#  'climax movi': 359603,
#  'movi creat': 1318181,
#  'creat offbeat': 442549,
#  'offbeat yet': 1400746,
#  'yet astoundingli': 2276738,
#  'astoundingli right': 123320,
#  'right feel': 1678873,
#  'feel wonder': 718340,
#  'wonder film': 2244376,
#  'film script': 736120,
#  'script music': 1748149,
#  'music act': 1335092,
#  'act imag': 14860,
#  'imag vanilla': 985465,
#  'sky sadli': 1838189,
#  'sadli superfici': 1711409,
#  'superfici bandwagon': 1957278,
#  'bandwagon movi': 157142,
#  'movi critic': 1318205,
#  'critic chide': 450570,
#  'chide order': 332572,
#  'order appear': 1424577,
#  'appear intellig': 99310,
#  'intellig excel': 1021381,
#  'dog': 551994,
#  'cat': 299856,
#  'back': 145660,
#  'home': 946120,
#  'old': 1407652,
#  'wise': 2233926,
#  'golden': 848742,
#  'retriev': 1666587,
#  'shadow': 1789912,
#  'american': 70712,
#  'bulldog': 259859,
#  'chanc': 313040,
#  'himalayan': 934942,
#  'sassi': 1719652,
#  'flee': 755856,
#  'ranch': 1603712,
#  'wilder': 2227580,
#  'reunit': 1667964,
#  'famili': 696461,
#  'homeward': 947937,
#  'bound': 232201,
#  'journey': 1062236,
#  'adventur': 32332,
#  'duwayn': 582642,
#  'dunham': 580866,
#  'remak': 1646971,
#  'sequel': 1775099,
#  'three': 2034707,
#  'year': 2273449,
#  'michael': 1272257,
#  'fox': 781456,
#  'perfect': 1477102,
#  'voice': 2174584,
#  'ov': 1436025,
#  'youth': 2281716,
#  'energi': 619844,
#  'bring': 246044,
#  'role': 1690051,
#  'salli': 1715066,
#  'field': 725527,
#  'voic': 2173548,
#  'amech': 69769,
#  'fantast': 702543,
#  'veteran': 2157886,
#  'actor': 18473,
#  'last': 1111041,
#  'visibl': 2170546,
#  'kim': 1084641,
#  'greist': 871113,
#  'laura': 1117741,
#  'burnford': 263650,
#  'seav': 1752721,
#  'robert': 1686051,
#  'hay': 908754,
#  'bob': 218495,
#  'seaver': 1752723,
#  'benji': 187661,
#  'thall': 2010179,
#  'peter': 1488364,
#  'veronica': 2155426,
#  'lauren': 1117969,
#  'hope': 951373,
#  'kevin': 1076659,
#  'chevalia': 331446,
#  'jami': 1045752,
#  'jean': 1049172,
#  'smart': 1846968,
#  'portray': 1532792,
#  'kate': 1071124,
#  'quit': 1595335,
#  'pet': 1488090,
#  'surviv': 1967063,
#  'taken': 1981897,
#  'river': 1683752,
#  'goner': 849990,
#  ...}

# %%
x_test_vec = cv.transform(x_test)

# %%
print(x_test_vec.shape)
# Out:
# (10000, 2286831)

# %% [markdown]
# ## Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb = MultinomialNB()

# %%
mnb.fit(x_vec, Y)
# Out:
# MultinomialNB()

# %%
y_t = mnb.predict(x_test_vec)

# %%
y_test = []
for i in range(len(y_t)) :
    if y_t[i] == 1 :
        y_test.append([i, 'pos'])
    else :
        y_test.append([i, 'neg'])

# %%
y_test = np.array(y_test)

# %%
dfy = pd.DataFrame(y_test, columns = ['Id', 'label'])

# %%
dfy.to_csv('answer.csv', index = False)

# %%
mnb.predict_proba(x_test_vec)
# Out:
# array([[1.00000000e+00, 3.38772631e-14],
#        [9.98168972e-01, 1.83102796e-03],
#        [1.00000000e+00, 2.57373093e-35],
#        ...,
#        [7.24657094e-27, 1.00000000e+00],
#        [2.65645081e-13, 1.00000000e+00],
#        [1.00000000e+00, 4.64574062e-43]])

# %%
y_t
# Out:
# array([0, 0, 0, ..., 1, 1, 0])

# %% [markdown]
# ## Multivariate Bernoulli Event Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
bnb = BernoulliNB()

# %%
bnb.fit(x_vec, Y)
# Out:
# BernoulliNB()

# %%
bnb.predict_proba(x_test_vec)
# Out:
# array([[1.00000000e+00, 5.48236453e-13],
#        [9.99617416e-01, 3.82583541e-04],
#        [1.00000000e+00, 6.14521393e-34],
#        ...,
#        [1.54521240e-20, 1.00000000e+00],
#        [1.66735203e-10, 1.00000000e+00],
#        [1.00000000e+00, 1.04841127e-36]])

# %%
y_bern = bnb.predict(x_test_vec)

# %%
y_test_bern = []
for i in range(len(y_bern)) :
    if y_bern[i] == 1 :
        y_test_bern.append([i, 'pos'])
    else :
        y_test_bern.append([i, 'neg'])

# %%
mnb.score(x_vec, Y)
# Out:
# 0.99485

# %%
dfnew = pd.DataFrame(y_test_bern, columns = ['Id', 'label'])
dfnew.to_csv('answer2.csv', index = False)
